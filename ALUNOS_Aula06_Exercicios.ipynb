# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardanevess/FATEC-MINERACO-DE-DADOS-2-SEM-2024/blob/master/ALUNOS_Aula06_Exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Exercícios**
#
# Aula 06 - Exercícios
#
# Prof. Anderson Vanin

# %% [markdown]
# Eduarda Neves Damasceno Silva

# %% [markdown]
# # 01 - Criação e Manipulação de Arrays
#
# Crie um array Numpy com 10 números inteiros aleatórios entre 1 e 20 e extraia os elementos pares.

# %%
import numpy as np

array = np.random.randint(1, 21, size=10)

pares = array[array % 2 == 0]

print("Array original:", array)
print("Elementos pares:", pares)
# Out:
# Array original: [16 19 19  3 16  8 15 16 11  4]
# Elementos pares: [16 16  8 16  4]

# %% [markdown]
# # 02 - Operações Aritméticas com Arrays
#
# Crie dois arrays de 10 números inteiros aleatórios entre 0 e 50 e realize operações de soma, subtração, multiplicação e divisão elemento a elemento.

# %%
import numpy as np

array1 = np.random.randint(0, 51, size=10)
array2 = np.random.randint(0, 51, size=10)

soma = array1 + array2
subtracao = array1 - array2
multiplicacao = array1 * array2
divisao = np.divide(array1, array2, out=np.zeros_like(array1, dtype=float), where=array2!=0)

print("Array 1:", array1)
print("Array 2:", array2)
print("Soma:", soma)
print("Subtração:", subtracao)
print("Multiplicação:", multiplicacao)
print("Divisão:", divisao)
# Out:
# Array 1: [ 4 15  6 44 16 49 41 16 36 35]
# Array 2: [29 48 40  9 23 37 45 19 26  3]
# Soma: [33 63 46 53 39 86 86 35 62 38]
# Subtração: [-25 -33 -34  35  -7  12  -4  -3  10  32]
# Multiplicação: [ 116  720  240  396  368 1813 1845  304  936  105]
# Divisão: [ 0.13793103  0.3125      0.15        4.88888889  0.69565217  1.32432432
#   0.91111111  0.84210526  1.38461538 11.66666667]

# %% [markdown]
# # 03 - Indexação e Slicing
#
# Dado um array Numpy com 20 números aleatórios entre 10 e 100, extraia os elementos entre a 5ª e a 15ª posição.

# %%
import numpy as np

array = np.random.randint(10, 101, size=20)

sub_array = array[4:15]

print("Array original:", array)
print("Elementos entre a 5ª e a 15ª posição:", sub_array)
# Out:
# Array original: [63 19 89 87 88 25 70 19 92 66 72 88 74 22 74 43 10 72 77 21]
# Elementos entre a 5ª e a 15ª posição: [88 25 70 19 92 66 72 88 74 22 74]

# %% [markdown]
# # 04 - Manipulação de Matrizes
#
# Crie uma matriz 3x3 com valores aleatórios entre 0 e 1, e encontre o valor máximo e mínimo.

# %%
import numpy as np

matriz = np.random.rand(3, 3)

valor_maximo = np.max(matriz)
valor_minimo = np.min(matriz)

print("Matriz 3x3:\n", matriz)
print("Valor máximo:", valor_maximo)
print("Valor mínimo:", valor_minimo)
# Out:
# Matriz 3x3:
#  [[0.76585219 0.53579572 0.0568694 ]
#  [0.83847594 0.13251655 0.46970766]
#  [0.08500419 0.01487645 0.56953622]]
# Valor máximo: 0.8384759395127586
# Valor mínimo: 0.014876446052253134

# %% [markdown]
# # 05 - Transformações em Arrays
#
# Crie um array de 12 números inteiros aleatórios entre 1 e 100 e reshape-o para uma matriz 4x3.

# %%
import numpy as np

array = np.random.randint(1, 101, size=12)

matriz = array.reshape(4, 3)

print("Array original:", array)
print("Matriz 4x3:\n", matriz)
# Out:
# Array original: [91 48 51 31 93 32 72 35 33 46 31 63]
# Matriz 4x3:
#  [[91 48 51]
#  [31 93 32]
#  [72 35 33]
#  [46 31 63]]

# %% [markdown]
# # 06 - Criação de DataFrames
#
# Crie um DataFrame com dados de 5 pessoas, onde cada pessoa tem nome, idade (entre 20 e 40), e cidade (escolha 3 cidades aleatórias).

# %%
import pandas as pd
import numpy as np

nomes = ['Eduarda', 'Sara', 'Iago', 'Pedro', 'Enzo']
idades = np.random.randint(20, 41, size=5)
cidades = np.random.choice(['Mauá', 'Santo André', 'Ribeirão'], size=5)

df = pd.DataFrame({
    'Nome': nomes,
    'Idade': idades,
    'Cidade': cidades
})

print(df)
# Out:
#       Nome  Idade       Cidade
# 0  Eduarda     37  Santo André
# 1     Sara     40         Mauá
# 2     Iago     27  Santo André
# 3    Pedro     39  Santo André
# 4     Enzo     30     Ribeirão

# %% [markdown]
# # 07 - Criação de DataFrame com Dados Sintéticos
#
# Crie um DataFrame fictício de vendas contendo colunas como Produto, Quantidade (entre 1 e 20), e Preço (entre 10 e 100).

# %%
import pandas as pd
import numpy as np


produtos = ['Esmalte', 'Rímel', 'Base', 'Batom', 'Delineador']
quantidades = np.random.randint(1, 21, size=5)
precos = np.random.randint(10, 101, size=5)

df_vendas = pd.DataFrame({
    'Produto': produtos,
    'Quantidade': quantidades,
    'Preço': precos
})

print(df_vendas)
# Out:
#       Produto  Quantidade  Preço
# 0     Esmalte          18     55
# 1       Rímel          12     84
# 2        Base          19     95
# 3       Batom           2     85
# 4  Delineador          18     42

# %% [markdown]
# # 08 - Filtragem de Dados
#
# Filtre o DataFrame criado no exercício anterior para mostrar apenas as vendas onde a quantidade é maior que 10.

# %%
df_filtrado = df_vendas[df_vendas['Quantidade'] > 10]

print(df_filtrado)
# Out:
#       Produto  Quantidade  Preço
# 0     Esmalte          18     55
# 1       Rímel          12     84
# 2        Base          19     95
# 4  Delineador          18     42

# %% [markdown]
# # 09 - Operações em Colunas
#
# Adicione uma coluna ao DataFrame com o valor total da venda (Quantidade * Preço).

# %%
df_vendas['Valor Total'] = df_vendas['Quantidade'] * df_vendas['Preço']

print(df_vendas)
# Out:
#       Produto  Quantidade  Preço  Valor Total
# 0     Esmalte          18     55          990
# 1       Rímel          12     84         1008
# 2        Base          19     95         1805
# 3       Batom           2     85          170
# 4  Delineador          18     42          756

# %% [markdown]
# # 10 - Agrupamento e Agregação
#
# Agrupe o DataFrame pelo campo Produto e calcule a soma das quantidades vendidas para cada produto.

# %%
import pandas as pd
import numpy as np

produtos = ['Esmalte', 'Rímel', 'Base', 'Batom', 'Delineador']
quantidades = np.random.randint(1, 21, size=5)
precos = np.random.randint(10, 101, size=5)

df_vendas = pd.DataFrame({
    'Produto': produtos,
    'Quantidade': quantidades,
    'Preço': precos
})

soma_quantidades = df_vendas.groupby('Produto')['Quantidade'].sum()

print("DataFrame de Vendas:\n", df_vendas)
print("\nSoma das Quantidades por Produto:\n", soma_quantidades)
# Out:
# DataFrame de Vendas:
#        Produto  Quantidade  Preço
# 0     Esmalte           3     58
# 1       Rímel           3     80
# 2        Base          20     30
# 3       Batom          10     80
# 4  Delineador          10     75
#
# Soma das Quantidades por Produto:
#  Produto
# Base          20
# Batom         10
# Delineador    10
# Esmalte        3
# Rímel          3
# Name: Quantidade, dtype: int64

# %% [markdown]
# # 11 - Gráfico de Linhas
#
# Crie um gráfico de linha que mostra a variação de preços de um produto fictício ao longo de 12 meses.

# %%
import matplotlib.pyplot as plt

meses = np.arange(1, 13)
precos = np.random.uniform(20, 100, size=12)

plt.plot(meses, precos, marker='o')
plt.title('Variação de Preços ao Longo de 12 Meses')
plt.xlabel('Mês')
plt.ylabel('Preço')
plt.grid(True)
plt.show()

# %% [markdown]
# # 12 - Gráfico de Barras
#
# Crie um gráfico de barras comparando a quantidade vendida de 5 produtos fictícios.

# %%
produtos = ['Café', 'Nescau', 'Açucar', 'Refrigerante', 'Chá']
quantidades = [15, 7, 10, 5, 8]

plt.bar(produtos, quantidades, color='skyblue')
plt.title('Quantidade Vendida de Produtos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %% [markdown]
# # 13 - Histograma
#
# Crie um histograma para mostrar a distribuição de idades em um conjunto de dados fictício de 100 pessoas.

# %%
idades = np.random.randint(20, 60, size=100)

plt.hist(idades, bins=10, edgecolor='black')
plt.title('Distribuição de Idades')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# # 14 - Gráfico de Dispersão
#
# Crie um gráfico de dispersão que mostre a relação entre altura e peso em um conjunto de dados fictício.

# %%
altura = np.random.uniform(150, 200, size=100)
peso = np.random.uniform(50, 100, size=100)

plt.scatter(altura, peso, alpha=0.7)
plt.title('Relação entre Altura e Peso')
plt.xlabel('Altura (cm)')
plt.ylabel('Peso (kg)')
plt.show()

# %% [markdown]
# # 15 - Customização de Gráficos
#
# Adicione título, rótulos de eixo e uma legenda ao gráfico de barras criado anteriormente.

# %%
import matplotlib.pyplot as plt

produtos = ['Café', 'Nescau', 'Açúcar', 'Refrigerante', 'Chá']
quantidades = [15, 7, 10, 5, 8]

plt.bar(produtos, quantidades, color='skyblue')
plt.title('Quantidade Vendida de Produtos')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.legend(['Quantidade'])
plt.show()

# %% [markdown]
# # 16 - Gráfico de Barras com Seaborn
#
# Use Seaborn para criar um gráfico de barras com os mesmos dados fictícios de quantidade vendida por produto.

# %%
import seaborn as sns

df_vendas = pd.DataFrame({
    'Produto': produtos,
    'Quantidade': quantidades
})

sns.barplot(x='Produto', y='Quantidade', data=df_vendas, palette='Blues_d')
plt.title('Quantidade Vendida de Produtos com Seaborn')
plt.show()
# Out:
# <ipython-input-22-a45a636dd8f9>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Produto', y='Quantidade', data=df_vendas, palette='Blues_d')

# %% [markdown]
# # 17 - Gráfico de Dispersão com Seaborn
#
# Recrie o gráfico de dispersão da relação entre altura e peso usando Seaborn, incluindo uma linha de regressão.

# %%
df_dispersao = pd.DataFrame({
    'Altura': altura,
    'Peso': peso
})

sns.lmplot(x='Altura', y='Peso', data=df_dispersao)
plt.title('Relação entre Altura e Peso com Linha de Regressão')
plt.show()

# %% [markdown]
# # 18 - Boxplot
#
# Crie um boxplot para visualizar a distribuição das idades em um conjunto de dados fictício de 50 pessoas.

# %%
idades = np.random.randint(20, 60, size=50)

sns.boxplot(idades, color='lightblue')
plt.title('Distribuição das Idades')
plt.xlabel('Idade')
plt.show()

# %% [markdown]
# # 19 - Heatmap
#
# Crie um heatmap para mostrar a correlação entre diferentes variáveis em um DataFrame fictício.

# %%
dados = np.random.rand(5, 5)
df_corr = pd.DataFrame(dados, columns=['A', 'B', 'C', 'D', 'E'])

sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap de Correlação')
plt.show()

# %% [markdown]
# # 20 - Pairplot
#
# Crie um pairplot para explorar relações entre várias variáveis em um conjunto de dados fictício.

# %%
df_pairplot = pd.DataFrame({
    'A': np.random.rand(100),
    'B': np.random.rand(100),
    'C': np.random.rand(100)
})

sns.pairplot(df_pairplot)
plt.title('Pairplot das Variáveis')
plt.show()
