# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardanevess/FATEC-MINERACO-DE-DADOS-2-SEM-2024/blob/master/Eduarda_Neves.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalando as Bibliotecas

# %%
# !pip install requests
# !pip install beautifulsoup4

# %% [markdown]
# Definindo a URL do Site

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://books.toscrape.com/catalogue/category/books/music_14/index.html'

# %% [markdown]
# Definindo Headers

# %%
headers = {"User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 OPR/113.0.0.0"}

# %% [markdown]
# Enviando a Requisição HTTP

# %%
response = requests.get(url,headers=headers)

# %% [markdown]
# Visualizando a Resposta da Requisição

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    Music | \n     Books to Scrape - Sandbox\n\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="\n    \n" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="sho
# ...

# %%
bonito = BeautifulSoup(response.text, 'html.parser')

# %%
print(bonito.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Music |
#      Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="
#
# " name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %% [markdown]
# Extraindo Produtos do HTML

# %%
produtos = bonito.find_all('article', class_='product_pod')
produtos[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="../../../rip-it-up-and-start-again_986/index.html"><img alt="Rip it Up and Start Again" class="thumbnail" src="../../../../media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/></a>
# </div>
# <p class="star-rating Five">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="../../../rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">Rip it Up and ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£35.02</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
nome_produto = produtos[0].find('h3').text
print("Produto Nome = ",nome_produto)
# Out:
# Produto Nome =  Rip it Up and ...

# %%
preco_produto = produtos[0].find_all('p', class_='price_color')[0].text
preco_produto
# Out:
# 'Â£35.02'

# %%
instock_produto = produtos[0].find_all('p', class_='availability')[0].text
instock_produto
# Out:
# '\n\n    \n        In stock\n    \n'

# %%
produtos = bonito.find_all('article', class_='product_pod')

# %%
produtos
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="../../../rip-it-up-and-start-again_986/index.html"><img alt="Rip it Up and Start Again" class="thumbnail" src="../../../../media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg"/></a>
#  </div>
#  <p class="star-rating Five">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../rip-it-up-and-start-again_986/index.html" title="Rip it Up and Start Again">Rip it Up and ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£35.02</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
import pandas as pd

# %% [markdown]
# Verificar se a requisição foi bem sucedida

# %%
if response.status_code == 200:
    print("Conexão bem-sucedida!")
    soup = BeautifulSoup(response.text, 'html.parser')
    produtos = soup.find_all('article', class_='product_pod')

    livros = []

    for produto in produtos:
        nome = produto.find('h3').text
        preco_str = produto.find('p', class_='price_color').text.replace('Â', '').replace('£', '')
        preco = float(preco_str)
        estoque = produto.find_all('p')[2].text.strip()
# Out:
# Conexão bem-sucedida!

# %% [markdown]
# #Exercício
# 1. Preço médio dos livros: Mostra o preço médio de todos os livros listados
# 2. Contagem de livros disponíveis: Iforma quantos livros estão disponíveis no estoque.
# 3. Livros mais caros: Exibe os 3 livros com preços mais altos na lista.

# %%
import pandas as pd

# Verificando se a requisição foi bem sucedida
if response.status_code == 200:
    print("Conexão bem-sucedida!")
    soup = BeautifulSoup(response.text, 'html.parser')
    produtos = soup.find_all('article', class_='product_pod')

    livros = []

    for produto in produtos:
        nome = produto.find('h3').text
        preco_str = produto.find('p', class_='price_color').text.replace('Â', '').replace('£', '')
        preco = float(preco_str)
        estoque = produto.find_all('p')[2].text.strip()

        # Adicionando o livro à lista
        livros.append({'nome': nome, 'preco': preco, 'estoque': estoque})

        print("Nome:", nome)
        print("Preço:", preco)
        print("Estoque:", estoque)
        print("-" * 20)

    # Criando um DataFrame com os dados dos livros
    df = pd.DataFrame(livros)

    # Calculando o preço médio
    preco_medio = df['preco'].mean()
    print(f"\nPreço médio dos livros: £{preco_medio:.2f}")

    # Contando os livros em estoque
    livros_em_estoque = df['estoque'].str.contains("In stock").sum()
    print(f"Total de livros em estoque: {livros_em_estoque}")

    # Encontrando os 3 livros mais caros
    livros_mais_caros = df.nlargest(3, 'preco')
    print("\nOs 3 livros mais caros são:")
    print(livros_mais_caros[['nome', 'preco']])
else:
    print("Erro ao acessar o site.")
# Out:
# Conexão bem-sucedida!
# Nome: Rip it Up and ...
# Preço: 35.02
# Estoque: In stock
# --------------------
# Nome: Our Band Could Be ...
# Preço: 57.25
# Estoque: In stock
# --------------------
# Nome: How Music Works
# Preço: 37.32
# Estoque: In stock
# --------------------
# Nome: Love Is a Mix ...
# Preço: 18.03
# Estoque: In stock
# --------------------
# Nome: Please Kill Me: The ...
# Preço: 31.19
# Estoque: In stock
# --------------------
# Nome: Kill 'Em and Leave: ...
# Preço: 45.05
# Estoque: In stock
# --------------------
# Nome: Chronicles, Vol. 1
# Preço: 52.6
# Estoque: In stock
# --------------------
# Nome: This Is Your Brain ...
# Preço: 38.4
# Estoque: In stock
# --------------------
# Nome: Orchestra of Exiles: The ...
# Preço: 12.36
# Estoque: In stock
# --------------------
# Nome: No One Here Gets ...
# Preço: 20.02
# Estoque: In stock
# --------------------
# Nome: Life
# Preço: 31.58
# Estoque: In stock
# --------------------
# ...
